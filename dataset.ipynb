# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("urbikn/sroie-datasetv2")

print("Path to dataset files:", path)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Resolving data files:   0%|          | 0/1001 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/402 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/401 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/1000 [00:00<?, ?files/s]
# Downloading data:   0%|          | 0/401 [00:00<?, ?files/s]
# Downloading data:   0%|          | 0/400 [00:00<?, ?files/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/401 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/400 [00:00<?, ? examples/s]

# %%
i = 1
ds['train'][i]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x1067>
