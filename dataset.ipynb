# %%
from datasets import load_dataset

ds = load_dataset("CC1984/mall_receipt_extraction_dataset")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 from datasets import load_dataset
# ----> 3 ds = load_dataset("CC1984/mall_receipt_extraction_dataset")
#
# File c:\Users\joyce\doc-digi\lib\site-packages\datasets\load.py:1708, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1705     return builder_instance.as_streaming_dataset(split=split)
#    1707 # Download and prepare data
# -> 1708 builder_instance.download_and_prepare(
#    1709     download_config=download_config,
#    1710     download_mode=download_mode,
#    1711     verification_mode=verification_mode,
#    1712     num_proc=num_proc,
#    1713     storage_options=storage_options,
#    1714 )
# ...
